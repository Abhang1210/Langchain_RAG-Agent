# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content i am using to create a RAG agent.",
    metadata={
        "source":"example.txt",
        "pages": 1,
        "author": "Abhang Panchal",
        "date_created":"2025-11-19"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Abhang Panchal', 'date_created': '2025-11-19'}, page_content='This is the main text content i am using to create a RAG agent.')

# %%
import os 
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text ={
    "../data/text_files/python_intro.txt": """Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and vibrant ecosystem of third-party packages make it suitable for a wide range of applications, from web development and data analysis to artificial intelligence and scientific computing.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

    Machine learning is a subset of artificial intelligence that enables systems to learn and improve
    from experience without being explicitly programmed. It focuses on developing computer programs
    that can access data and use it to learn for themselves.

    Types of Machine Learning:
    1. Supervised Learning: Learning with labeled data
    2. Unsupervised Learning: Finding patterns in unlabeled data
    3. Reinforcement Learning: Learning through rewards and penalties

    Applications include image recognition, speech processing, and recommendation systems
        
        
    """
}

for filepath, content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text file created successfully.")
# Out:
# Sample text file created successfully.

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and vibrant ecosystem of third-party packages make it suitable for a wide range of applications, from web development and data analysis to artificial intelligence and scientific computing.")]

# %%
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

all_documents = dir_loader.load()
print(all_documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\n    Machine learning is a subset of artificial intelligence that enables systems to learn and improve\n    from experience without being explicitly programmed. It focuses on developing computer programs\n    that can access data and use it to learn for themselves.\n\n    Types of Machine Learning:\n    1. Supervised Learning: Learning with labeled data\n    2. Unsupervised Learning: Finding patterns in unlabeled data\n    3. Reinforcement Learning: Learning through rewards and penalties\n\n    Applications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content="Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and vibrant ecosystem of third-party packages make it suitable for a wide range of applications, from web development and data analysis to artificial intelligence and scientific computing.")]

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader, TextLoader

pdf_loader = DirectoryLoader(
    "../data/pdf",
    glob="*.pdf",
    loader_cls=PyMuPDFLoader
)

pdf_documents = pdf_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='LangChain Essentials\n1'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content='Create Agent\n3'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, page_content='●\nAgent Demonstration\n●\nLangChain Agent Fundamentals\n●\nCustomize your Agent\n3\nOutline\n1\n2\n4'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3}, page_content='LangChain Agent\nReAct Agent\n●\nReAct: Synergizing Reasoning and Acting in \nLanguage Models.\n○\nReason\n○\nAction\n○\nObservation\n●\nBuilt with  LangGraph\n○\nPersistence \n○\nStreaming\n○\nInterrupts (Human-In-The-Loop)\n○\nTracing (LangSmith Observability & Evals)\n○\nDeployment (LangSmith Deployment)\n○\n●\nmodel\ntools\nrequest\nresult\n🛠🪚\n🔩⚙\naction\nobservation'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4}, page_content='LangChain Agent\nReAct Agent\n●\nReAct: Synergizing Reasoning and Acting in \nLanguage Models.\n○\nReason\n○\nAction\n○\nObservation\n●\nBuilt with  LangGraph\n○\nPersistence \n○\nStreaming\n○\nInterrupts (Human-In-The-Loop)\n○\nTracing (LangSmith Observability & Evals)\n○\nDeployment (LangSmith Deployment)\n●\nQuick to build\nfrom langchain.agents import \ncreate_agent\nagent = create_agent(\n    model="openai:gpt-5",\nsystem_prompt=”you are…”,\ntools=tools\n)'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 5}, page_content='Lab Setup\nmodel\ntools\nrequest\nresult\ndef execute_sql(query: str) -> str:\n   """Execute a SQLite command and return results."""\ndb\ncustomer\ntracks\nAgent\n●\nChinook (music shop) \nexample database\n●\nThe agent is not provided \nthe schema (it will have to \nﬁgure it out!)\n●\nNote - you would want to \nadd further safeguards in \na production se\ue009ing!\n●\nRun in an editor and then \nin the agent debugger!'), Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\agent_ppt.pdf', 'file_path': '..\\data\\pdf\\agent_ppt.pdf', 'total_pages': 43, 'format': 'PDF 1.4', 'title': 'LangChain V1 Essentials', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate':  ...
